# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dropout, Dense
from keras.optimizers import RMSprop, Adagrad, Adadelta, Adam, Adamax, Nadam, SGD, TFOptimizer
from keras.layers import CuDNNLSTM, Flatten, LSTM, Reshape, BatchNormalization, Activation, UpSampling1D, ZeroPadding1D, PReLU
from random import shuffle
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import scipy.io
import time
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0'  # CPU:-1; GPU0: 1; GPU1: 0;
# usually 0

class DeepPhyLSTM:
    # Initialize the class
    def __init__(self, eta, eta_t, g, ag, ag_c, lift, Phi_t, save_path):

        # data
        self.eta = eta
        self.eta_t = eta_t
        self.g = g
        self.ag = ag
        self.lift = lift
        self.ag_c = ag_c
        self.Phi_t = Phi_t
        self.save_path = 'C:/Users/livin/Downloads/Seismic Thesis/Seismic Thesis/Thesis/San Bernardino Hotel 23287/EW/PhyLSTM/Save Path'

        # tf placeholders and graph
        self.sess = tf.Session(config=tf.ConfigProto(allow_soft_placement=True,
                                                     log_device_placement=True))
        
        # placeholders for data
        self.learning_rate = tf.placeholder(tf.float32, shape=[])
        self.best_loss = tf.placeholder(tf.float32, shape=[])
        self.eta_tf = tf.placeholder(tf.float32, shape=[None, None, self.eta.shape[2]])
        self.eta_t_tf = tf.placeholder(tf.float32, shape=[None, None, self.eta.shape[2]])
        self.g_tf = tf.placeholder(tf.float32, shape=[None, None, self.eta.shape[2]])
        self.ag_tf = tf.placeholder(tf.float32, shape=[None, None, 1])
        self.lift_tf = tf.placeholder(tf.float32, shape=[None, None, 1])
        self.ag_c_tf = tf.placeholder(tf.float32, shape=[None, None, 1])
        self.Phi_tf = tf.placeholder(tf.float32, shape=[None, self.eta.shape[1], self.eta.shape[1]])

        # physics informed neural networks
        self.eta_pred, self.eta_t_pred, self.eta_tt_pred, self.eta_dot_pred, self.g_pred, self.g_t_pred = self.net_structure(self.ag_tf)
        self.eta_t_pred_c, self.eta_dot_pred_c, self.g_t_pred_c, self.g_dot_pred_c, self.lift_c_pred = self.net_f(self.ag_c_tf)

        # loss
        # for measurements
        self.loss_u = tf.reduce_mean(tf.square(self.eta_tf - self.eta_pred))
        self.loss_udot = tf.reduce_mean(tf.square(self.eta_t_tf - self.eta_dot_pred))
        self.loss_g = tf.reduce_mean(tf.square(self.g_tf - self.g_pred))
        # for collocations
        self.loss_ut_c = tf.reduce_mean(tf.square(self.eta_t_pred_c - self.eta_dot_pred_c))
        self.loss_gt_c = tf.reduce_mean(tf.square(self.g_t_pred_c - self.g_dot_pred_c))
        self.loss_e = tf.reduce_mean(tf.square(tf.matmul(self.lift_tf, tf.ones([self.lift.shape[0], 1, self.eta.shape[2]], dtype=tf.float32)) - self.lift_c_pred))

        self.loss = self.loss_u + self.loss_udot + self.loss_ut_c + self.loss_gt_c + self.loss_e

        # optimizers
        self.optimizer = tf.contrib.opt.ScipyOptimizerInterface(self.loss,
                                                                method='L-BFGS-B',
                                                                options={'maxiter': 20000,
                                                                         'maxfun': 50000,
                                                                         'maxcor': 50,
                                                                         'maxls': 50,
                                                                         'ftol': 1 * np.finfo(float).eps})

        self.optimizer_Adam = tf.train.AdamOptimizer(learning_rate = self.learning_rate)
        self.train_op = self.optimizer_Adam.minimize(self.loss)

        init = tf.global_variables_initializer()
        self.sess.run(init)

        self.saver = tf.train.Saver()

    def LSTM_model(self, X):
        model = Sequential()
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False, input_shape=(None, 1)))
        model.add(Activation('relu'))
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False))
        model.add(Activation('relu'))
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False))
        model.add(Activation('relu'))
        # model.add(Dense(100))
        model.add(Dense(3*self.eta.shape[2]))
        y = model(X)
        return y

    def LSTM_model_f(self, X):
        model = Sequential()
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False, input_shape=(None, 3*self.eta.shape[2])))
        model.add(Activation('relu'))
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False))
        model.add(Activation('relu'))
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False))
        model.add(Activation('relu'))
        # model.add(Dense(100))
        model.add(Dense(self.eta.shape[2]))
        y = model(X)
        return y

    def LSTM_model_g(self, X):
        model = Sequential()
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False, input_shape=(None, 2*self.eta.shape[2])))
        model.add(Activation('relu'))
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False))
        model.add(Activation('relu'))
        model.add(CuDNNLSTM(100, return_sequences=True, stateful=False))
        model.add(Activation('relu'))
        # model.add(Dense(100))
        model.add(Dense(self.eta.shape[2]))
        y = model(X)
        return y

    def net_structure(self, ag):
        output = self.LSTM_model(ag)
        eta = output[:, :, 0:self.eta.shape[2]]
        eta_dot = output[:, :, self.eta.shape[2]:2*self.eta.shape[2]]
        g = output[:, :, 2*self.eta.shape[2]:]

        eta_t = tf.matmul(self.Phi_tf, eta)
        eta_tt = tf.matmul(self.Phi_tf, eta_dot)
        g_t = tf.matmul(self.Phi_tf, g)

        return eta, eta_t, eta_tt, eta_dot, g, g_t

    def net_f(self, ag):
        eta, eta_t, eta_tt, eta_dot, g, g_t = self.net_structure(ag)
        f = self.LSTM_model_f(tf.concat([eta, eta_dot, g], 2))
        lift = eta_tt + f

        eta_dot1 = eta_dot[:, :, 0:1]
        g_dot = self.LSTM_model_g(tf.concat([eta_dot1, g], 2))
        return eta_t, eta_dot, g_t, g_dot, lift
    
    def train(self, num_epochs, learning_rate, bfgs):

        Loss_u = []
        Loss_udot = []
        Loss_ut_c = []
        Loss_gt_c = []
        Loss_g = []
        Loss_e = []
        Loss = []
        Loss_val = []
        best_loss = 100

        for epoch in range(num_epochs):

            Ind = list(range(self.ag.shape[0]))
            shuffle(Ind)
            ratio_split = 0.8
            Ind_tr = Ind[0:round(ratio_split * self.ag.shape[0])]
            Ind_val = Ind[round(ratio_split * self.ag.shape[0]):]

            self.ag_tr = self.ag[Ind_tr]
            self.eta_tr = self.eta[Ind_tr]
            self.eta_t_tr = self.eta_t[Ind_tr]
            self.g_tr = self.g[Ind_tr]
            self.ag_val = self.ag[Ind_val]
            self.eta_val = self.eta[Ind_val]
            self.eta_t_val = self.eta_t[Ind_val]
            self.g_val = self.g[Ind_val]

            start_time = time.time()

            tf_dict = {self.eta_tf: self.eta_tr, self.eta_t_tf: self.eta_t_tr, self.g_tf: self.g_tr,
                       self.ag_tf: self.ag_tr, self.lift_tf: self.lift, self.ag_c_tf: self.ag_c,
                       self.Phi_tf: self.Phi_t, self.learning_rate: learning_rate}

            tf_dict_val = {self.eta_tf: self.eta_val, self.eta_t_tf: self.eta_t_val, self.g_tf: self.g_val,
                           self.ag_tf: self.ag_val, self.lift_tf: self.lift, self.ag_c_tf: self.ag_c,
                           self.Phi_tf: self.Phi_t, self.learning_rate: learning_rate}

            self.sess.run(self.train_op, tf_dict)

            loss_value, learning_rate_value = self.sess.run([self.loss, self.learning_rate], tf_dict)
            loss_val_value = self.sess.run(self.loss, tf_dict_val)

            Loss_u.append(self.sess.run(self.loss_u, tf_dict))
            Loss_udot.append(self.sess.run(self.loss_udot, tf_dict))
            Loss_g.append(self.sess.run(self.loss_g, tf_dict))
            Loss_ut_c.append(self.sess.run(self.loss_ut_c, tf_dict))
            Loss_gt_c.append(self.sess.run(self.loss_gt_c, tf_dict))
            Loss_e.append(self.sess.run(self.loss_e, tf_dict))
            Loss.append(self.sess.run(self.loss, tf_dict))
            Loss_val.append(self.sess.run(self.loss, tf_dict_val))

            # Save the best val model
            if loss_val_value < best_loss and loss_val_value < 1e-2:
                best_loss = loss_val_value

                # self.saver.save(sess=self.sess, save_path=self.save_path)

            elapsed = time.time() - start_time
            print('Epoch: %d, Loss: %.3e, Loss_val: %.3e, Best_loss: %.3e, Time: %.2f, Learning Rate: %.3e'
                  % (epoch, loss_value, loss_val_value, best_loss, elapsed, learning_rate_value))

        if bfgs == 1:

            start_time = time.time()

            tf_dict_all = {self.eta_tf: self.eta_tr, self.eta_t_tf: self.eta_t_tr, self.g_tf: self.g_tr,
                       self.ag_tf: self.ag_tr, self.lift_tf: self.lift, self.ag_c_tf: self.ag_c,
                       self.Phi_tf: self.Phi_t, self.learning_rate: learning_rate, self.best_loss: best_loss}

            self.optimizer.minimize(self.sess,
                                    feed_dict=tf_dict_all,
                                    fetches=[self.loss, self.best_loss],
                                    loss_callback=self.callback)
                                    # step_callback=self.step_callback)

            Loss_u.append(self.sess.run(self.loss_u, tf_dict_all))
            Loss_udot.append(self.sess.run(self.loss_udot, tf_dict_all))
            Loss_g.append(self.sess.run(self.loss_g, tf_dict))
            Loss_ut_c.append(self.sess.run(self.loss_ut_c, tf_dict_all))
            Loss_gt_c.append(self.sess.run(self.loss_gt_c, tf_dict_all))
            Loss_e.append(self.sess.run(self.loss_e, tf_dict_all))
            Loss.append(self.sess.run(self.loss, tf_dict_all))
            Loss_val.append(self.sess.run(self.loss, tf_dict_val))

        return Loss_u, Loss_udot, Loss_g, Loss_ut_c, Loss_gt_c, Loss_e, Loss, Loss_val, best_loss

    def callback(self, loss, best_loss):

        global Loss_BFGS
        global Loss_val_BFGS
        Loss_BFGS = np.append(Loss_BFGS, loss)

        loss_val = self.sess.run(self.loss, feed_dict={self.eta_tf: self.eta_val, self.eta_t_tf: self.eta_t_val, self.g_tf: self.g_val,
                               self.ag_tf: self.ag_val, self.lift_tf: self.lift, self.ag_c_tf: self.ag_c, self.Phi_tf: self.Phi_t})

        Loss_val_BFGS = np.append(Loss_val_BFGS, loss_val)

        print('Loss: %.3e, Loss_val: %.3e, Best_loss: %.3e'
              % (loss, loss_val, best_loss))

    def step_callback(self, loss):

        loss_val = self.sess.run(self.loss, feed_dict={self.eta_tf: self.eta_val, self.eta_t_tf: self.eta_t_val, self.g_tf: self.g_val,
                                 self.ag_tf: self.ag_val, self.lift_tf: self.lift, self.ag_c_tf: self.ag_c, self.Phi_tf: self.Phi_t})

        eta_star, eta_t_star, eta_tt_star, eta_dot_star, g_star = self.predict(self.ag_val, self.Phi_t[0:self.ag_val.shape[0]])
        loss_val = np.mean(np.square(eta_star, self.eta_val))

        print('Loss_val: %.3e', loss_val)

    def callback1(self, loss):
        print('Loss:', loss)

    def predict(self, ag_star, Phi_star):

        tf_dict = {self.ag_tf: ag_star, self.Phi_tf: Phi_star}

        eta_star = self.sess.run(self.eta_pred, tf_dict)
        eta_t_star = self.sess.run(self.eta_t_pred, tf_dict)
        eta_tt_star = self.sess.run(self.eta_tt_pred, tf_dict)
        eta_dot_star = self.sess.run(self.eta_dot_pred, tf_dict)
        g_star = self.sess.run(self.g_pred, tf_dict)

        return eta_star, eta_t_star, eta_tt_star, eta_dot_star, g_star

    def predict_c(self, ag_star, Phi_star):

        tf_dict = {self.ag_c_tf: ag_star, self.Phi_tf: Phi_star}
        lift_star = self.sess.run(self.lift_c_pred, tf_dict)

        return lift_star

    def predict_best_model(self, path, ag_star, Phi_star):
        self.saver.restore(sess=self.sess, save_path=path)

        tf_dict = {self.ag_tf: ag_star, self.Phi_tf: Phi_star}

        eta_star = self.sess.run(self.eta_pred, tf_dict)
        eta_t_star = self.sess.run(self.eta_t_pred, tf_dict)
        eta_tt_star = self.sess.run(self.eta_tt_pred, tf_dict)
        eta_dot_star = self.sess.run(self.eta_dot_pred, tf_dict)
        g_star = self.sess.run(self.g_pred, tf_dict)

        return eta_star, eta_t_star, eta_tt_star, eta_dot_star, g_star

if __name__ == "__main__": 

    dataDir = 'C:/Users/livin/Downloads/Seismic Thesis/Seismic Thesis/Thesis Data/San Bernardino Hotel 23287/EW/PhyLSTM/'
    # Replace with your directory PATH and use forward/slashes/

    mat = scipy.io.loadmat(dataDir + 'Data/data_PHY_23287_EW.mat')
    # Complete with your directory PATH and use forward/slashes/
    
    t = mat['time']
    dt = 0.02
    
    #n1 = int(dt / 0.005)
    #t = t[::n1]

    ag_data = mat['input_GM_23287_EW'][:, :]  # ag, ad, av
    u_data = mat['target_X_23287_EW'][:, :, 0]
    ut_data = mat['target_Xd_23287_EW'][:, :, 0]
    utt_data = mat['target_Xdd_23287_EW'][:, :, 0]
    ag_data = ag_data.reshape([ag_data.shape[0], ag_data.shape[1], 1])
    u_data = u_data.reshape([u_data.shape[0], u_data.shape[1], 1])
    ut_data = ut_data.reshape([ut_data.shape[0], ut_data.shape[1], 1])
    utt_data = utt_data.reshape([utt_data.shape[0], utt_data.shape[1], 1])

    ag_pred = mat['input_pred_GM_23287_EW'][4:6, :]  # ag, ad, av
    u_pred = mat['target_pred_X_23287_EW'][4:6, :, 0]
    ut_pred = mat['target_pred_Xd_23287_EW'][4:6, :, 0]
    utt_pred = mat['target_pred_Xdd_23287_EW'][4:6, :, 0]
    ag_pred = ag_pred.reshape([ag_pred.shape[0], ag_pred.shape[1], 1])
    u_pred = u_pred.reshape([u_pred.shape[0], u_pred.shape[1], 1])
    ut_pred = ut_pred.reshape([ut_pred.shape[0], ut_pred.shape[1], 1])
    utt_pred = utt_pred.reshape([utt_pred.shape[0], utt_pred.shape[1], 1])

    n = u_data.shape[1]
    phi1 = np.concatenate([np.array([-3 / 2, 2, -1 / 2]), np.zeros([n - 3, ])])
    temp1 = np.concatenate([-1 / 2 * np.identity(n - 2), np.zeros([n - 2, 2])], axis=1)
    temp2 = np.concatenate([np.zeros([n - 2, 2]), 1 / 2 * np.identity(n - 2)], axis=1)
    phi2 = temp1 + temp2
    phi3 = np.concatenate([np.zeros([n - 3, ]), np.array([1 / 2, -2, 3 / 2])])
    Phi_t0 = 1 / dt * np.concatenate(
            [np.reshape(phi1, [1, phi1.shape[0]]), phi2, np.reshape(phi3, [1, phi3.shape[0]])], axis=0)
    Phi_t0 = np.reshape(Phi_t0, [1, n, n])

    ag_star = ag_data
    eta_star = u_data
    eta_t_star = ut_data
    eta_tt_star = utt_data
    ag_c_star = np.concatenate([ag_data, ag_pred[0:53]])
    lift_star = -ag_c_star
    eta_c_star = np.concatenate([u_data, u_pred[0:53]])
    eta_t_c_star = np.concatenate([ut_data, ut_pred[0:53]])
    eta_tt_c_star = np.concatenate([utt_data, utt_pred[0:53]])

    eta = eta_star
    ag = ag_star
    lift = lift_star
    eta_t = eta_t_star
    eta_tt = eta_tt_star
    g = -eta_tt - ag
    ag_c = ag_c_star

    # Training Data
    eta_train = eta
    ag_train = ag
    lift_train = lift
    eta_t_train = eta_t
    eta_tt_train = eta_tt
    g_train = g
    ag_c_train = ag_c

    Loss_BFGS = np.empty([0])
    Loss_val_BFGS = np.empty([0])
    Phi_t = np.repeat(Phi_t0, ag_c_star.shape[0], axis=0)

with tf.device('/device:GPU:0'):
    # with tf.device('/cpu:0'):
    
    config = tf.ConfigProto()
    config.gpu_options.allow_growth = True
    #config.gpu_options.per_process_gpu_memory_fraction = 0.4 #
    #gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.6)
    #session = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options))
    session = tf.Session(config=config)
   # tf.Session(config=tf.ConfigProto(log_device_placement=True))#

    # Training
    model = DeepPhyLSTM(eta_train, eta_t_train, g_train, ag_train, ag_c, lift, Phi_t, save_path='C:/Users/livin/Downloads/Seismic Thesis/Seismic Thesis/Thesis/San Bernardino Hotel 23287/EW/PhyLSTM/Save Path')

    Loss_u1, Loss_udot1, Loss_g1, Loss_ut_c1, Loss_gt_c1, Loss_e1, Loss1, Loss_val1, best_loss1 = model.train(num_epochs=5000, learning_rate=1e-3, bfgs=1)

    train_loss = Loss1
    test_loss = Loss_val1
    best_loss = best_loss1

    plt.figure()
    plt.plot(np.log(train_loss), label='loss')
    plt.plot(np.log(test_loss), label='loss_val')
    plt.legend()

    # Results
    # Training performance
    X_train = ag_data
    y_train_ref = u_data
    yt_train_ref = ut_data
    ytt_train_ref = utt_data
    lift_train_ref = -X_train
    g_train_ref = -ytt_train_ref + lift_train_ref

    eta, eta_t, eta_tt, eta_dot, g = model.predict(X_train, np.repeat(Phi_t0, len(X_train), axis=0))
    lift = model.predict_c(X_train, np.repeat(Phi_t0, len(X_train), axis=0))
    y_train_pred = eta
    yt_train_pred = eta_t
    ytt_train_pred = eta_tt
    g_train_pred = -eta_tt + lift

    dof = 0
    for ii in range(len(y_train_ref)):
        plt.figure()
        plt.plot(y_train_ref[ii, :, dof], '-', label='True')
        plt.plot(y_train_pred[ii, :, dof], '--', label='Predict')
        plt.title('Training_u')
        plt.legend()

    for ii in range(len(y_train_ref)):
        plt.figure()
        plt.plot(yt_train_ref[ii, :, dof], label='True')
        plt.plot(yt_train_pred[ii, :, dof], label='Predict')
        plt.title('Training_u_t')
        plt.legend()

    for ii in range(len(y_train_ref)):
        plt.figure()
        plt.plot(ytt_train_ref[ii, :, dof], label='True')
        plt.plot(ytt_train_pred[ii, :, dof], label='Predict')
        plt.title('Training_u_tt')
        plt.legend()

    for ii in range(len(y_train_ref)):
        plt.figure()
        plt.plot(g_train_ref[ii, :, dof], label='True')
        plt.plot(g_train_pred[ii, :, dof], label='Predict')
        plt.title('Training_g')
        plt.legend()

    for ii in range(len(y_train_ref)):
        plt.figure()
        plt.plot(y_train_ref[ii, :, dof], g_train_ref[ii, :, dof], label='True')
        plt.plot(y_train_pred[ii, :, dof], g_train_pred[ii, :, dof], label='Predict')
        plt.title('Training_Hysteresis')
        plt.legend()

    # Prediction performance
    X_pred = ag_pred
    y_pred_ref = u_pred
    yt_pred_ref = ut_pred
    ytt_pred_ref = utt_pred
    lift_pred_ref = -X_pred
    g_pred_ref = -ytt_pred_ref + lift_pred_ref

    eta, eta_t, eta_tt, eta_dot, g = model.predict(X_pred, np.repeat(Phi_t0, len(X_pred), axis=0))
    lift = model.predict_c(X_pred, np.repeat(Phi_t0, len(X_pred), axis=0))
    y_pred = eta
    yt_pred = eta_t
    ytt_pred = eta_tt
    g_pred = -eta_tt + lift

    dof = 0
    for ii in range(len(y_pred_ref)):
        plt.figure()
        plt.plot(y_pred_ref[ii, :, dof], label='True')
        plt.plot(y_pred[ii, :, dof], label='Predict')
        plt.title('Prediction_u')
        plt.legend()

    for ii in range(len(yt_pred_ref)): #Index_pred
        plt.figure()
        plt.plot(yt_pred_ref[ii, :, dof], label='True')
        plt.plot(yt_pred[ii, :, dof], label='Predict')
        plt.title('Prediction_u_t')
        plt.legend()

    for ii in range(len(ytt_pred_ref)):
        plt.figure()
        plt.plot(ytt_pred_ref[ii, :, dof], label='True')
        plt.plot(ytt_pred[ii, :, dof], label='Predict')
        plt.title('Prediction_u_tt')
        plt.legend()

    for ii in range(len(g_pred_ref)):
        plt.figure()
        plt.plot(g_pred_ref[ii, :, dof], label='True')
        plt.plot(g_pred[ii, :, dof], label='Predict')
        plt.title('Prediction_g')
        plt.legend()

    for ii in range(len(y_pred_ref)):
        plt.figure()
        plt.plot(y_pred_ref[ii, :, dof], g_pred_ref[ii, :, dof], label='True')
        plt.plot(y_pred[ii, :, dof], g_pred[ii, :, dof], label='Predict')
        plt.title('Prediction_Hysteresis')
        plt.legend()

scipy.io.savemat(dataDir + 'Results/results_PhyLSTM_23287_EW_3rdFloor_Copy1.mat',
                 {'y_train_ref': y_train_ref, 'yt_train_ref': yt_train_ref, 'ytt_train_ref': ytt_train_ref, 'g_train_ref': g_train_ref,
                  'y_train_pred': y_train_pred, 'yt_train_pred': yt_train_pred, 'ytt_train_pred': ytt_train_pred, 'g_train_pred': g_train_pred,
                  'y_pred_ref': y_pred_ref, 'yt_pred_ref': yt_pred_ref, 'ytt_pred_ref': ytt_pred_ref, 'g_pred_ref': g_pred_ref,
                  'y_pred': y_pred, 'yt_pred': yt_pred, 'ytt_pred': ytt_pred, 'g_pred': g_pred,
                  'X_train': X_train, 'X_pred': X_pred, 'time': t, 'dt': dt,
                  'train_loss': train_loss, 'test_loss': test_loss, 'best_loss': best_loss})
# Out:
# Using TensorFlow backend.
# Device mapping:
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: NVIDIA GeForce GTX 1650, pci bus id: 0000:01:00.0, compute capability: 7.5
#
# WARNING:tensorflow:From C:\Users\livin\anaconda3\envs\lstm\lib\site-packages\tensorflow_core\python\ops\resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# Epoch: 0, Loss: 3.025e-02, Loss_val: 1.480e-01, Best_loss: 1.000e+02, Time: 15.40, Learning Rate: 1.000e-03
# Epoch: 1, Loss: 4.937e-02, Loss_val: 6.163e-02, Best_loss: 1.000e+02, Time: 10.62, Learning Rate: 1.000e-03
# Epoch: 2, Loss: 6.168e-02, Loss_val: 2.790e-03, Best_loss: 2.790e-03, Time: 10.70, Learning Rate: 1.000e-03
# Epoch: 3, Loss: 5.794e-02, Loss_val: 1.854e-02, Best_loss: 2.790e-03, Time: 10.72, Learning Rate: 1.000e-03
# Epoch: 4, Loss: 3.915e-02, Loss_val: 1.010e-01, Best_loss: 2.790e-03, Time: 10.73, Learning Rate: 1.000e-03
# Epoch: 5, Loss: 5.946e-02, Loss_val: 6.310e-03, Best_loss: 2.790e-03, Time: 10.86, Learning Rate: 1.000e-03
# Epoch: 6, Loss: 4.658e-02, Loss_val: 6.164e-02, Best_loss: 2.790e-03, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 7, Loss: 5.422e-02, Loss_val: 2.339e-02, Best_loss: 2.790e-03, Time: 10.95, Learning Rate: 1.000e-03
# Epoch: 8, Loss: 4.954e-02, Loss_val: 4.739e-02, Best_loss: 2.790e-03, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 9, Loss: 4.902e-02, Loss_val: 5.459e-02, Best_loss: 2.790e-03, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 10, Loss: 4.870e-02, Loss_val: 4.157e-02, Best_loss: 2.790e-03, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 11, Loss: 4.888e-02, Loss_val: 4.910e-02, Best_loss: 2.790e-03, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 12, Loss: 5.718e-02, Loss_val: 2.724e-03, Best_loss: 2.724e-03, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 13, Loss: 5.646e-02, Loss_val: 7.579e-03, Best_loss: 2.724e-03, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 14, Loss: 4.860e-02, Loss_val: 4.192e-02, Best_loss: 2.724e-03, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 15, Loss: 4.759e-02, Loss_val: 4.075e-02, Best_loss: 2.724e-03, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 16, Loss: 5.349e-02, Loss_val: 1.751e-02, Best_loss: 2.724e-03, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 17, Loss: 4.518e-02, Loss_val: 4.920e-02, Best_loss: 2.724e-03, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 18, Loss: 5.243e-02, Loss_val: 1.576e-02, Best_loss: 2.724e-03, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 19, Loss: 4.665e-02, Loss_val: 4.080e-02, Best_loss: 2.724e-03, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 20, Loss: 5.110e-02, Loss_val: 1.622e-02, Best_loss: 2.724e-03, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 21, Loss: 5.439e-02, Loss_val: 2.552e-03, Best_loss: 2.552e-03, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 22, Loss: 5.209e-02, Loss_val: 7.014e-03, Best_loss: 2.552e-03, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 23, Loss: 1.563e-02, Loss_val: 1.733e-01, Best_loss: 2.552e-03, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 24, Loss: 5.307e-02, Loss_val: 9.784e-04, Best_loss: 9.784e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 25, Loss: 5.238e-02, Loss_val: 2.748e-03, Best_loss: 9.784e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 26, Loss: 4.258e-02, Loss_val: 4.514e-02, Best_loss: 9.784e-04, Time: 11.61, Learning Rate: 1.000e-03
# Epoch: 27, Loss: 5.115e-02, Loss_val: 1.789e-03, Best_loss: 9.784e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 28, Loss: 2.501e-02, Loss_val: 1.200e-01, Best_loss: 9.784e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 29, Loss: 4.934e-02, Loss_val: 5.410e-03, Best_loss: 9.784e-04, Time: 11.32, Learning Rate: 1.000e-03
# Epoch: 30, Loss: 2.515e-02, Loss_val: 1.158e-01, Best_loss: 9.784e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 31, Loss: 2.442e-02, Loss_val: 1.142e-01, Best_loss: 9.784e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 32, Loss: 4.848e-02, Loss_val: 5.632e-03, Best_loss: 9.784e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 33, Loss: 3.914e-02, Loss_val: 4.452e-02, Best_loss: 9.784e-04, Time: 11.19, Learning Rate: 1.000e-03
# Epoch: 34, Loss: 4.496e-02, Loss_val: 1.533e-02, Best_loss: 9.784e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 35, Loss: 2.479e-02, Loss_val: 1.056e-01, Best_loss: 9.784e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 36, Loss: 2.445e-02, Loss_val: 1.029e-01, Best_loss: 9.784e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 37, Loss: 2.459e-02, Loss_val: 1.024e-01, Best_loss: 9.784e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 38, Loss: 3.879e-02, Loss_val: 3.596e-02, Best_loss: 9.784e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 39, Loss: 4.273e-02, Loss_val: 1.533e-02, Best_loss: 9.784e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 40, Loss: 4.232e-02, Loss_val: 1.597e-02, Best_loss: 9.784e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 41, Loss: 3.503e-02, Loss_val: 4.408e-02, Best_loss: 9.784e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 42, Loss: 4.077e-02, Loss_val: 1.606e-02, Best_loss: 9.784e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 43, Loss: 4.177e-02, Loss_val: 9.055e-03, Best_loss: 9.784e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 44, Loss: 4.084e-02, Loss_val: 8.443e-03, Best_loss: 9.784e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 45, Loss: 3.278e-02, Loss_val: 4.182e-02, Best_loss: 9.784e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 46, Loss: 3.151e-02, Loss_val: 4.834e-02, Best_loss: 9.784e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 47, Loss: 2.605e-02, Loss_val: 7.703e-02, Best_loss: 9.784e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 48, Loss: 2.110e-02, Loss_val: 8.810e-02, Best_loss: 9.784e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 49, Loss: 1.664e-02, Loss_val: 1.079e-01, Best_loss: 9.784e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 50, Loss: 1.690e-02, Loss_val: 1.124e-01, Best_loss: 9.784e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 51, Loss: 3.940e-02, Loss_val: 8.988e-04, Best_loss: 8.988e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 52, Loss: 3.681e-02, Loss_val: 1.647e-02, Best_loss: 8.988e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 53, Loss: 2.442e-02, Loss_val: 7.124e-02, Best_loss: 8.988e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 54, Loss: 3.010e-02, Loss_val: 4.227e-02, Best_loss: 8.988e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 55, Loss: 2.918e-02, Loss_val: 4.264e-02, Best_loss: 8.988e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 56, Loss: 2.087e-02, Loss_val: 7.984e-02, Best_loss: 8.988e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 57, Loss: 2.290e-02, Loss_val: 7.146e-02, Best_loss: 8.988e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 58, Loss: 3.643e-02, Loss_val: 7.783e-03, Best_loss: 8.988e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 59, Loss: 2.775e-02, Loss_val: 4.336e-02, Best_loss: 8.988e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 60, Loss: 2.943e-02, Loss_val: 3.541e-02, Best_loss: 8.988e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 61, Loss: 2.036e-02, Loss_val: 7.417e-02, Best_loss: 8.988e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 62, Loss: 3.307e-02, Loss_val: 1.580e-02, Best_loss: 8.988e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 63, Loss: 2.802e-02, Loss_val: 3.545e-02, Best_loss: 8.988e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 64, Loss: 3.539e-02, Loss_val: 1.138e-03, Best_loss: 8.988e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 65, Loss: 3.438e-02, Loss_val: 5.148e-03, Best_loss: 8.988e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 66, Loss: 2.002e-02, Loss_val: 6.888e-02, Best_loss: 8.988e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 67, Loss: 2.328e-02, Loss_val: 5.470e-02, Best_loss: 8.988e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 68, Loss: 3.424e-02, Loss_val: 2.071e-03, Best_loss: 8.988e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 69, Loss: 2.585e-02, Loss_val: 4.069e-02, Best_loss: 8.988e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 70, Loss: 2.254e-02, Loss_val: 5.433e-02, Best_loss: 8.988e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 71, Loss: 2.675e-02, Loss_val: 3.543e-02, Best_loss: 8.988e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 72, Loss: 2.529e-02, Loss_val: 3.897e-02, Best_loss: 8.988e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 73, Loss: 2.642e-02, Loss_val: 3.566e-02, Best_loss: 8.988e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 74, Loss: 2.602e-02, Loss_val: 3.651e-02, Best_loss: 8.988e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 75, Loss: 3.329e-02, Loss_val: 8.165e-04, Best_loss: 8.165e-04, Time: 11.19, Learning Rate: 1.000e-03
# Epoch: 76, Loss: 1.927e-02, Loss_val: 6.497e-02, Best_loss: 8.165e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 77, Loss: 3.092e-02, Loss_val: 1.100e-02, Best_loss: 8.165e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 78, Loss: 2.519e-02, Loss_val: 3.463e-02, Best_loss: 8.165e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 79, Loss: 2.504e-02, Loss_val: 3.425e-02, Best_loss: 8.165e-04, Time: 11.27, Learning Rate: 1.000e-03
# Epoch: 80, Loss: 2.188e-02, Loss_val: 5.022e-02, Best_loss: 8.165e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 81, Loss: 3.248e-02, Loss_val: 4.471e-04, Best_loss: 4.471e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 82, Loss: 3.124e-02, Loss_val: 4.356e-03, Best_loss: 4.471e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 83, Loss: 1.418e-02, Loss_val: 8.179e-02, Best_loss: 4.471e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 84, Loss: 3.092e-02, Loss_val: 5.022e-03, Best_loss: 4.471e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 85, Loss: 2.401e-02, Loss_val: 3.400e-02, Best_loss: 4.471e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 86, Loss: 2.004e-02, Loss_val: 5.307e-02, Best_loss: 4.471e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 87, Loss: 2.269e-02, Loss_val: 4.038e-02, Best_loss: 4.471e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 88, Loss: 1.360e-02, Loss_val: 8.136e-02, Best_loss: 4.471e-04, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 89, Loss: 2.755e-02, Loss_val: 1.571e-02, Best_loss: 4.471e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 90, Loss: 2.286e-02, Loss_val: 3.651e-02, Best_loss: 4.471e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 91, Loss: 1.622e-02, Loss_val: 6.572e-02, Best_loss: 4.471e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 92, Loss: 2.248e-02, Loss_val: 3.796e-02, Best_loss: 4.471e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 93, Loss: 3.025e-02, Loss_val: 5.411e-03, Best_loss: 4.471e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 94, Loss: 1.992e-02, Loss_val: 4.863e-02, Best_loss: 4.471e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 95, Loss: 2.435e-02, Loss_val: 3.255e-02, Best_loss: 4.471e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 96, Loss: 2.617e-02, Loss_val: 4.967e-02, Best_loss: 4.471e-04, Time: 10.96, Learning Rate: 1.000e-03
# Epoch: 97, Loss: 3.685e-02, Loss_val: 6.896e-03, Best_loss: 4.471e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 98, Loss: 2.486e-02, Loss_val: 4.688e-02, Best_loss: 4.471e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 99, Loss: 2.136e-02, Loss_val: 6.190e-02, Best_loss: 4.471e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 100, Loss: 2.560e-02, Loss_val: 4.837e-02, Best_loss: 4.471e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 101, Loss: 3.305e-02, Loss_val: 1.406e-02, Best_loss: 4.471e-04, Time: 12.41, Learning Rate: 1.000e-03
# Epoch: 102, Loss: 2.415e-02, Loss_val: 5.012e-02, Best_loss: 4.471e-04, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 103, Loss: 2.360e-02, Loss_val: 4.933e-02, Best_loss: 4.471e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 104, Loss: 2.005e-02, Loss_val: 6.387e-02, Best_loss: 4.471e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 105, Loss: 2.497e-02, Loss_val: 3.959e-02, Best_loss: 4.471e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 106, Loss: 2.387e-02, Loss_val: 4.172e-02, Best_loss: 4.471e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 107, Loss: 2.160e-02, Loss_val: 4.912e-02, Best_loss: 4.471e-04, Time: 11.68, Learning Rate: 1.000e-03
# Epoch: 108, Loss: 3.051e-02, Loss_val: 7.475e-03, Best_loss: 4.471e-04, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 109, Loss: 2.055e-02, Loss_val: 5.231e-02, Best_loss: 4.471e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 110, Loss: 2.283e-02, Loss_val: 4.125e-02, Best_loss: 4.471e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 111, Loss: 3.163e-02, Loss_val: 2.344e-03, Best_loss: 4.471e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 112, Loss: 2.848e-02, Loss_val: 1.537e-02, Best_loss: 4.471e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 113, Loss: 3.099e-02, Loss_val: 1.205e-03, Best_loss: 4.471e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 114, Loss: 2.794e-02, Loss_val: 1.527e-02, Best_loss: 4.471e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 115, Loss: 2.973e-02, Loss_val: 4.582e-03, Best_loss: 4.471e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 116, Loss: 2.753e-02, Loss_val: 1.495e-02, Best_loss: 4.471e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 117, Loss: 2.226e-02, Loss_val: 3.756e-02, Best_loss: 4.471e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 118, Loss: 2.091e-02, Loss_val: 4.391e-02, Best_loss: 4.471e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 119, Loss: 2.002e-02, Loss_val: 4.914e-02, Best_loss: 4.471e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 120, Loss: 2.222e-02, Loss_val: 3.704e-02, Best_loss: 4.471e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 121, Loss: 2.072e-02, Loss_val: 4.438e-02, Best_loss: 4.471e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 122, Loss: 2.276e-02, Loss_val: 3.298e-02, Best_loss: 4.471e-04, Time: 10.94, Learning Rate: 1.000e-03
# Epoch: 123, Loss: 2.175e-02, Loss_val: 3.727e-02, Best_loss: 4.471e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 124, Loss: 2.892e-02, Loss_val: 4.235e-03, Best_loss: 4.471e-04, Time: 11.19, Learning Rate: 1.000e-03
# Epoch: 125, Loss: 2.918e-02, Loss_val: 1.840e-03, Best_loss: 4.471e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 126, Loss: 2.918e-02, Loss_val: 1.538e-03, Best_loss: 4.471e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 127, Loss: 2.173e-02, Loss_val: 3.429e-02, Best_loss: 4.471e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 128, Loss: 2.910e-02, Loss_val: 3.990e-04, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 129, Loss: 2.571e-02, Loss_val: 1.438e-02, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 130, Loss: 2.127e-02, Loss_val: 3.408e-02, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 131, Loss: 2.543e-02, Loss_val: 1.466e-02, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 132, Loss: 2.770e-02, Loss_val: 4.257e-03, Best_loss: 3.990e-04, Time: 10.96, Learning Rate: 1.000e-03
# Epoch: 133, Loss: 2.755e-02, Loss_val: 4.362e-03, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 134, Loss: 2.736e-02, Loss_val: 4.321e-03, Best_loss: 3.990e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 135, Loss: 1.920e-02, Loss_val: 4.070e-02, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 136, Loss: 1.821e-02, Loss_val: 4.432e-02, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 137, Loss: 1.898e-02, Loss_val: 4.065e-02, Best_loss: 3.990e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 138, Loss: 2.067e-02, Loss_val: 3.181e-02, Best_loss: 3.990e-04, Time: 10.94, Learning Rate: 1.000e-03
# Epoch: 139, Loss: 2.067e-02, Loss_val: 3.120e-02, Best_loss: 3.990e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 140, Loss: 2.659e-02, Loss_val: 4.212e-03, Best_loss: 3.990e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 141, Loss: 2.037e-02, Loss_val: 4.164e-02, Best_loss: 3.990e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 142, Loss: 3.840e-02, Loss_val: 1.730e-02, Best_loss: 3.990e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 143, Loss: 2.965e-02, Loss_val: 7.307e-03, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 144, Loss: 1.965e-02, Loss_val: 5.826e-02, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 145, Loss: 2.405e-02, Loss_val: 2.839e-02, Best_loss: 3.990e-04, Time: 10.96, Learning Rate: 1.000e-03
# Epoch: 146, Loss: 2.140e-02, Loss_val: 4.319e-02, Best_loss: 3.990e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 147, Loss: 3.032e-02, Loss_val: 5.714e-03, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 148, Loss: 2.317e-02, Loss_val: 3.784e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 149, Loss: 2.950e-02, Loss_val: 8.932e-03, Best_loss: 3.990e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 150, Loss: 2.198e-02, Loss_val: 4.439e-02, Best_loss: 3.990e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 151, Loss: 2.114e-02, Loss_val: 4.337e-02, Best_loss: 3.990e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 152, Loss: 2.864e-02, Loss_val: 6.628e-03, Best_loss: 3.990e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 153, Loss: 2.967e-02, Loss_val: 2.015e-03, Best_loss: 3.990e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 154, Loss: 2.767e-02, Loss_val: 8.047e-03, Best_loss: 3.990e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 155, Loss: 1.933e-02, Loss_val: 4.291e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 156, Loss: 2.889e-02, Loss_val: 8.314e-04, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 157, Loss: 2.248e-02, Loss_val: 2.786e-02, Best_loss: 3.990e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 158, Loss: 2.520e-02, Loss_val: 1.495e-02, Best_loss: 3.990e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 159, Loss: 2.067e-02, Loss_val: 3.564e-02, Best_loss: 3.990e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 160, Loss: 2.685e-02, Loss_val: 5.097e-03, Best_loss: 3.990e-04, Time: 11.36, Learning Rate: 1.000e-03
# Epoch: 161, Loss: 1.766e-02, Loss_val: 4.524e-02, Best_loss: 3.990e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 162, Loss: 2.667e-02, Loss_val: 4.827e-03, Best_loss: 3.990e-04, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 163, Loss: 1.893e-02, Loss_val: 4.036e-02, Best_loss: 3.990e-04, Time: 11.30, Learning Rate: 1.000e-03
# Epoch: 164, Loss: 2.269e-02, Loss_val: 2.069e-02, Best_loss: 3.990e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 165, Loss: 1.440e-02, Loss_val: 5.712e-02, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 166, Loss: 2.608e-02, Loss_val: 4.805e-03, Best_loss: 3.990e-04, Time: 11.27, Learning Rate: 1.000e-03
# Epoch: 167, Loss: 2.557e-02, Loss_val: 6.301e-03, Best_loss: 3.990e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 168, Loss: 2.113e-02, Loss_val: 2.517e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 169, Loss: 1.849e-02, Loss_val: 3.638e-02, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 170, Loss: 2.014e-02, Loss_val: 2.818e-02, Best_loss: 3.990e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 171, Loss: 2.488e-02, Loss_val: 6.416e-03, Best_loss: 3.990e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 172, Loss: 2.437e-02, Loss_val: 7.682e-03, Best_loss: 3.990e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 173, Loss: 2.278e-02, Loss_val: 1.410e-02, Best_loss: 3.990e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 174, Loss: 2.235e-02, Loss_val: 1.543e-02, Best_loss: 3.990e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 175, Loss: 2.530e-02, Loss_val: 1.892e-03, Best_loss: 3.990e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 176, Loss: 2.507e-02, Loss_val: 2.044e-03, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 177, Loss: 1.752e-02, Loss_val: 3.620e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 178, Loss: 1.876e-02, Loss_val: 2.932e-02, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 179, Loss: 2.183e-02, Loss_val: 1.535e-02, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 180, Loss: 1.862e-02, Loss_val: 2.997e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 181, Loss: 1.719e-02, Loss_val: 3.616e-02, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 182, Loss: 1.939e-02, Loss_val: 2.537e-02, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 183, Loss: 1.381e-02, Loss_val: 5.049e-02, Best_loss: 3.990e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 184, Loss: 2.364e-02, Loss_val: 6.027e-03, Best_loss: 3.990e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 185, Loss: 2.134e-02, Loss_val: 1.521e-02, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 186, Loss: 1.389e-02, Loss_val: 4.824e-02, Best_loss: 3.990e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 187, Loss: 2.433e-02, Loss_val: 5.404e-04, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 188, Loss: 2.406e-02, Loss_val: 1.695e-03, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 189, Loss: 1.934e-02, Loss_val: 2.293e-02, Best_loss: 3.990e-04, Time: 11.68, Learning Rate: 1.000e-03
# Epoch: 190, Loss: 1.352e-02, Loss_val: 4.965e-02, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 191, Loss: 1.819e-02, Loss_val: 2.727e-02, Best_loss: 3.990e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 192, Loss: 2.403e-02, Loss_val: 2.038e-03, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 193, Loss: 2.257e-02, Loss_val: 6.259e-03, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 194, Loss: 2.385e-02, Loss_val: 9.205e-04, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 195, Loss: 1.771e-02, Loss_val: 2.812e-02, Best_loss: 3.990e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 196, Loss: 1.954e-02, Loss_val: 1.993e-02, Best_loss: 3.990e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 197, Loss: 2.364e-02, Loss_val: 7.458e-04, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 198, Loss: 2.263e-02, Loss_val: 4.754e-03, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 199, Loss: 2.333e-02, Loss_val: 1.452e-03, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 200, Loss: 2.316e-02, Loss_val: 1.424e-03, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 201, Loss: 2.243e-02, Loss_val: 4.411e-03, Best_loss: 3.990e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 202, Loss: 1.502e-02, Loss_val: 3.745e-02, Best_loss: 3.990e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 203, Loss: 2.209e-02, Loss_val: 5.604e-03, Best_loss: 3.990e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 204, Loss: 1.929e-02, Loss_val: 1.778e-02, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 205, Loss: 1.575e-02, Loss_val: 3.343e-02, Best_loss: 3.990e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 206, Loss: 2.208e-02, Loss_val: 4.457e-03, Best_loss: 3.990e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 207, Loss: 1.549e-02, Loss_val: 3.373e-02, Best_loss: 3.990e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 208, Loss: 1.984e-02, Loss_val: 1.388e-02, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 209, Loss: 1.780e-02, Loss_val: 2.304e-02, Best_loss: 3.990e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 210, Loss: 1.851e-02, Loss_val: 1.984e-02, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 211, Loss: 1.963e-02, Loss_val: 1.379e-02, Best_loss: 3.990e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 212, Loss: 2.267e-02, Loss_val: 4.341e-04, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 213, Loss: 1.859e-02, Loss_val: 1.797e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 214, Loss: 2.219e-02, Loss_val: 1.672e-03, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 215, Loss: 2.122e-02, Loss_val: 5.603e-03, Best_loss: 3.990e-04, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 216, Loss: 2.140e-02, Loss_val: 4.878e-03, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 217, Loss: 2.214e-02, Loss_val: 2.361e-03, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 218, Loss: 1.506e-02, Loss_val: 3.316e-02, Best_loss: 3.990e-04, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 219, Loss: 1.734e-02, Loss_val: 2.214e-02, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 220, Loss: 1.655e-02, Loss_val: 2.519e-02, Best_loss: 3.990e-04, Time: 10.96, Learning Rate: 1.000e-03
# Epoch: 221, Loss: 1.723e-02, Loss_val: 2.278e-02, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 222, Loss: 2.248e-02, Loss_val: 1.064e-03, Best_loss: 3.990e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 223, Loss: 2.217e-02, Loss_val: 1.581e-03, Best_loss: 3.990e-04, Time: 10.95, Learning Rate: 1.000e-03
# Epoch: 224, Loss: 1.500e-02, Loss_val: 3.305e-02, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 225, Loss: 1.669e-02, Loss_val: 2.633e-02, Best_loss: 3.990e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 226, Loss: 1.526e-02, Loss_val: 3.247e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 227, Loss: 2.279e-02, Loss_val: 2.683e-03, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 228, Loss: 2.075e-02, Loss_val: 5.639e-03, Best_loss: 3.990e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 229, Loss: 1.977e-02, Loss_val: 1.464e-02, Best_loss: 3.990e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 230, Loss: 2.305e-02, Loss_val: 7.110e-03, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 231, Loss: 2.158e-02, Loss_val: 2.215e-03, Best_loss: 3.990e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 232, Loss: 1.592e-02, Loss_val: 3.406e-02, Best_loss: 3.990e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 233, Loss: 2.163e-02, Loss_val: 9.692e-04, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 234, Loss: 1.823e-02, Loss_val: 2.007e-02, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 235, Loss: 2.179e-02, Loss_val: 2.142e-03, Best_loss: 3.990e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 236, Loss: 1.880e-02, Loss_val: 1.383e-02, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 237, Loss: 1.811e-02, Loss_val: 1.960e-02, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 238, Loss: 2.057e-02, Loss_val: 4.452e-03, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 239, Loss: 1.461e-02, Loss_val: 3.289e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 240, Loss: 1.749e-02, Loss_val: 2.029e-02, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 241, Loss: 1.262e-02, Loss_val: 4.040e-02, Best_loss: 3.990e-04, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 242, Loss: 1.664e-02, Loss_val: 2.394e-02, Best_loss: 3.990e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 243, Loss: 9.693e-03, Loss_val: 5.539e-02, Best_loss: 3.990e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 244, Loss: 2.100e-02, Loss_val: 2.361e-03, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 245, Loss: 1.374e-02, Loss_val: 3.544e-02, Best_loss: 3.990e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 246, Loss: 1.518e-02, Loss_val: 2.662e-02, Best_loss: 3.990e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 247, Loss: 1.440e-02, Loss_val: 3.133e-02, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 248, Loss: 2.075e-02, Loss_val: 8.638e-04, Best_loss: 3.990e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 249, Loss: 1.434e-02, Loss_val: 2.969e-02, Best_loss: 3.990e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 250, Loss: 1.325e-02, Loss_val: 3.464e-02, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 251, Loss: 1.421e-02, Loss_val: 2.902e-02, Best_loss: 3.990e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 252, Loss: 1.864e-02, Loss_val: 8.913e-03, Best_loss: 3.990e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 253, Loss: 1.994e-02, Loss_val: 1.536e-03, Best_loss: 3.990e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 254, Loss: 1.296e-02, Loss_val: 3.414e-02, Best_loss: 3.990e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 255, Loss: 1.990e-02, Loss_val: 7.697e-04, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 256, Loss: 1.663e-02, Loss_val: 1.608e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 257, Loss: 1.262e-02, Loss_val: 3.382e-02, Best_loss: 3.990e-04, Time: 11.19, Learning Rate: 1.000e-03
# Epoch: 258, Loss: 1.642e-02, Loss_val: 1.660e-02, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 259, Loss: 1.303e-02, Loss_val: 2.959e-02, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 260, Loss: 1.961e-02, Loss_val: 1.183e-03, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 261, Loss: 1.867e-02, Loss_val: 4.966e-03, Best_loss: 3.990e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 262, Loss: 1.501e-02, Loss_val: 1.912e-02, Best_loss: 3.990e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 263, Loss: 1.512e-02, Loss_val: 1.878e-02, Best_loss: 3.990e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 264, Loss: 9.794e-03, Loss_val: 4.472e-02, Best_loss: 3.990e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 265, Loss: 1.230e-02, Loss_val: 3.213e-02, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 266, Loss: 1.841e-02, Loss_val: 4.189e-03, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 267, Loss: 1.169e-02, Loss_val: 3.292e-02, Best_loss: 3.990e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 268, Loss: 1.507e-02, Loss_val: 1.737e-02, Best_loss: 3.990e-04, Time: 10.95, Learning Rate: 1.000e-03
# Epoch: 269, Loss: 1.858e-02, Loss_val: 2.454e-03, Best_loss: 3.990e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 270, Loss: 1.420e-02, Loss_val: 2.028e-02, Best_loss: 3.990e-04, Time: 11.88, Learning Rate: 1.000e-03
# Epoch: 271, Loss: 1.571e-02, Loss_val: 1.203e-02, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 272, Loss: 1.237e-02, Loss_val: 2.742e-02, Best_loss: 3.990e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 273, Loss: 1.187e-02, Loss_val: 2.888e-02, Best_loss: 3.990e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 274, Loss: 1.715e-02, Loss_val: 4.375e-03, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 275, Loss: 1.414e-02, Loss_val: 1.844e-02, Best_loss: 3.990e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 276, Loss: 1.424e-02, Loss_val: 1.910e-02, Best_loss: 3.990e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 277, Loss: 8.481e-03, Loss_val: 4.469e-02, Best_loss: 3.990e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 278, Loss: 1.341e-02, Loss_val: 1.991e-02, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 279, Loss: 9.742e-03, Loss_val: 3.880e-02, Best_loss: 3.990e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 280, Loss: 1.370e-02, Loss_val: 2.000e-02, Best_loss: 3.990e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 281, Loss: 1.192e-02, Loss_val: 2.673e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 282, Loss: 1.879e-02, Loss_val: 1.541e-02, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 283, Loss: 3.423e-02, Loss_val: 3.038e-02, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 284, Loss: 3.285e-02, Loss_val: 8.320e-03, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 285, Loss: 1.993e-02, Loss_val: 6.269e-02, Best_loss: 3.990e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 286, Loss: 2.215e-02, Loss_val: 3.694e-02, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 287, Loss: 3.184e-02, Loss_val: 3.289e-03, Best_loss: 3.990e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 288, Loss: 2.322e-02, Loss_val: 3.800e-02, Best_loss: 3.990e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 289, Loss: 1.873e-02, Loss_val: 4.923e-02, Best_loss: 3.990e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 290, Loss: 2.221e-02, Loss_val: 3.236e-02, Best_loss: 3.990e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 291, Loss: 2.918e-02, Loss_val: 1.004e-03, Best_loss: 3.990e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 292, Loss: 2.643e-02, Loss_val: 7.799e-03, Best_loss: 3.990e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 293, Loss: 2.384e-02, Loss_val: 1.465e-02, Best_loss: 3.990e-04, Time: 11.29, Learning Rate: 1.000e-03
# Epoch: 294, Loss: 1.837e-02, Loss_val: 3.726e-02, Best_loss: 3.990e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 295, Loss: 1.999e-02, Loss_val: 2.732e-02, Best_loss: 3.990e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 296, Loss: 1.863e-02, Loss_val: 3.092e-02, Best_loss: 3.990e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 297, Loss: 2.409e-02, Loss_val: 5.698e-03, Best_loss: 3.990e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 298, Loss: 2.507e-02, Loss_val: 1.137e-03, Best_loss: 3.990e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 299, Loss: 2.450e-02, Loss_val: 3.299e-04, Best_loss: 3.299e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 300, Loss: 1.966e-02, Loss_val: 2.175e-02, Best_loss: 3.299e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 301, Loss: 2.412e-02, Loss_val: 9.861e-04, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 302, Loss: 2.380e-02, Loss_val: 4.597e-04, Best_loss: 3.299e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 303, Loss: 1.963e-02, Loss_val: 1.893e-02, Best_loss: 3.299e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 304, Loss: 1.935e-02, Loss_val: 1.879e-02, Best_loss: 3.299e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 305, Loss: 1.614e-02, Loss_val: 3.331e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 306, Loss: 1.590e-02, Loss_val: 3.347e-02, Best_loss: 3.299e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 307, Loss: 1.859e-02, Loss_val: 1.921e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 308, Loss: 2.250e-02, Loss_val: 1.004e-03, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 309, Loss: 2.217e-02, Loss_val: 1.748e-03, Best_loss: 3.299e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 310, Loss: 1.502e-02, Loss_val: 3.396e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 311, Loss: 1.699e-02, Loss_val: 2.434e-02, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 312, Loss: 1.696e-02, Loss_val: 2.315e-02, Best_loss: 3.299e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 313, Loss: 2.154e-02, Loss_val: 1.730e-03, Best_loss: 3.299e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 314, Loss: 2.177e-02, Loss_val: 8.198e-04, Best_loss: 3.299e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 315, Loss: 2.029e-02, Loss_val: 6.456e-03, Best_loss: 3.299e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 316, Loss: 2.023e-02, Loss_val: 5.571e-03, Best_loss: 3.299e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 317, Loss: 2.107e-02, Loss_val: 9.822e-04, Best_loss: 3.299e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 318, Loss: 1.705e-02, Loss_val: 1.857e-02, Best_loss: 3.299e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 319, Loss: 2.086e-02, Loss_val: 8.763e-04, Best_loss: 3.299e-04, Time: 11.20, Learning Rate: 1.000e-03
# Epoch: 320, Loss: 1.323e-02, Loss_val: 3.423e-02, Best_loss: 3.299e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 321, Loss: 1.674e-02, Loss_val: 1.829e-02, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 322, Loss: 1.594e-02, Loss_val: 2.145e-02, Best_loss: 3.299e-04, Time: 11.34, Learning Rate: 1.000e-03
# Epoch: 323, Loss: 1.658e-02, Loss_val: 1.797e-02, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 324, Loss: 1.732e-02, Loss_val: 1.390e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 325, Loss: 1.536e-02, Loss_val: 2.251e-02, Best_loss: 3.299e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 326, Loss: 1.630e-02, Loss_val: 1.779e-02, Best_loss: 3.299e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 327, Loss: 2.003e-02, Loss_val: 4.295e-04, Best_loss: 3.299e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 328, Loss: 1.974e-02, Loss_val: 8.134e-04, Best_loss: 3.299e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 329, Loss: 1.550e-02, Loss_val: 1.960e-02, Best_loss: 3.299e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 330, Loss: 1.859e-02, Loss_val: 5.172e-03, Best_loss: 3.299e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 331, Loss: 1.929e-02, Loss_val: 1.472e-03, Best_loss: 3.299e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 332, Loss: 1.824e-02, Loss_val: 5.415e-03, Best_loss: 3.299e-04, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 333, Loss: 1.032e-02, Loss_val: 4.064e-02, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 334, Loss: 1.911e-02, Loss_val: 6.179e-04, Best_loss: 3.299e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 335, Loss: 1.901e-02, Loss_val: 3.756e-04, Best_loss: 3.299e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 336, Loss: 1.777e-02, Loss_val: 5.441e-03, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 337, Loss: 1.792e-02, Loss_val: 4.287e-03, Best_loss: 3.299e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 338, Loss: 1.739e-02, Loss_val: 6.163e-03, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 339, Loss: 1.579e-02, Loss_val: 1.310e-02, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 340, Loss: 1.681e-02, Loss_val: 8.605e-03, Best_loss: 3.299e-04, Time: 10.96, Learning Rate: 1.000e-03
# Epoch: 341, Loss: 1.825e-02, Loss_val: 2.082e-03, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 342, Loss: 1.466e-02, Loss_val: 1.752e-02, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 343, Loss: 1.730e-02, Loss_val: 4.454e-03, Best_loss: 3.299e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 344, Loss: 1.397e-02, Loss_val: 1.880e-02, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 345, Loss: 1.359e-02, Loss_val: 2.049e-02, Best_loss: 3.299e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 346, Loss: 1.158e-02, Loss_val: 2.972e-02, Best_loss: 3.299e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 347, Loss: 1.390e-02, Loss_val: 1.868e-02, Best_loss: 3.299e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 348, Loss: 1.679e-02, Loss_val: 4.798e-03, Best_loss: 3.299e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 349, Loss: 1.725e-02, Loss_val: 2.025e-03, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 350, Loss: 1.680e-02, Loss_val: 4.289e-03, Best_loss: 3.299e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 351, Loss: 1.395e-02, Loss_val: 1.679e-02, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 352, Loss: 1.393e-02, Loss_val: 1.698e-02, Best_loss: 3.299e-04, Time: 11.55, Learning Rate: 1.000e-03
# Epoch: 353, Loss: 8.891e-03, Loss_val: 3.980e-02, Best_loss: 3.299e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 354, Loss: 1.498e-02, Loss_val: 1.553e-02, Best_loss: 3.299e-04, Time: 11.10, Learning Rate: 1.000e-03
# Epoch: 355, Loss: 1.482e-02, Loss_val: 1.603e-02, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 356, Loss: 1.507e-02, Loss_val: 1.250e-02, Best_loss: 3.299e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 357, Loss: 1.457e-02, Loss_val: 1.243e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 358, Loss: 1.196e-02, Loss_val: 2.604e-02, Best_loss: 3.299e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 359, Loss: 1.596e-02, Loss_val: 5.444e-03, Best_loss: 3.299e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 360, Loss: 1.175e-02, Loss_val: 2.558e-02, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 361, Loss: 1.052e-02, Loss_val: 2.877e-02, Best_loss: 3.299e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 362, Loss: 1.377e-02, Loss_val: 1.514e-02, Best_loss: 3.299e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 363, Loss: 1.588e-02, Loss_val: 4.916e-03, Best_loss: 3.299e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 364, Loss: 1.634e-02, Loss_val: 1.854e-03, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 365, Loss: 1.413e-02, Loss_val: 1.285e-02, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 366, Loss: 1.558e-02, Loss_val: 4.490e-03, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 367, Loss: 1.104e-02, Loss_val: 2.466e-02, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 368, Loss: 1.555e-02, Loss_val: 4.800e-03, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 369, Loss: 1.051e-02, Loss_val: 2.566e-02, Best_loss: 3.299e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 370, Loss: 1.031e-02, Loss_val: 2.760e-02, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 371, Loss: 1.307e-02, Loss_val: 1.415e-02, Best_loss: 3.299e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 372, Loss: 1.510e-02, Loss_val: 3.852e-03, Best_loss: 3.299e-04, Time: 10.96, Learning Rate: 1.000e-03
# Epoch: 373, Loss: 1.283e-02, Loss_val: 1.445e-02, Best_loss: 3.299e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 374, Loss: 1.565e-02, Loss_val: 1.096e-03, Best_loss: 3.299e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 375, Loss: 1.494e-02, Loss_val: 3.454e-03, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 376, Loss: 1.265e-02, Loss_val: 1.321e-02, Best_loss: 3.299e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 377, Loss: 1.475e-02, Loss_val: 3.419e-03, Best_loss: 3.299e-04, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 378, Loss: 1.517e-02, Loss_val: 1.047e-03, Best_loss: 3.299e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 379, Loss: 1.450e-02, Loss_val: 3.747e-03, Best_loss: 3.299e-04, Time: 10.97, Learning Rate: 1.000e-03
# Epoch: 380, Loss: 1.231e-02, Loss_val: 1.331e-02, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 381, Loss: 1.002e-02, Loss_val: 2.318e-02, Best_loss: 3.299e-04, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 382, Loss: 1.434e-02, Loss_val: 3.501e-03, Best_loss: 3.299e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 383, Loss: 1.505e-02, Loss_val: 1.135e-03, Best_loss: 3.299e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 384, Loss: 1.604e-02, Loss_val: 5.543e-03, Best_loss: 3.299e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 385, Loss: 1.648e-02, Loss_val: 2.659e-02, Best_loss: 3.299e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 386, Loss: 2.385e-02, Loss_val: 1.155e-02, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 387, Loss: 1.464e-02, Loss_val: 2.140e-02, Best_loss: 3.299e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 388, Loss: 1.462e-02, Loss_val: 2.098e-02, Best_loss: 3.299e-04, Time: 11.09, Learning Rate: 1.000e-03
# Epoch: 389, Loss: 2.009e-02, Loss_val: 7.722e-03, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 390, Loss: 1.603e-02, Loss_val: 2.261e-02, Best_loss: 3.299e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 391, Loss: 1.777e-02, Loss_val: 5.510e-03, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 392, Loss: 1.419e-02, Loss_val: 2.262e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 393, Loss: 1.345e-02, Loss_val: 2.787e-02, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 394, Loss: 1.518e-02, Loss_val: 1.509e-02, Best_loss: 3.299e-04, Time: 11.08, Learning Rate: 1.000e-03
# Epoch: 395, Loss: 1.734e-02, Loss_val: 1.263e-03, Best_loss: 3.299e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 396, Loss: 1.480e-02, Loss_val: 1.639e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 397, Loss: 1.710e-02, Loss_val: 6.044e-03, Best_loss: 3.299e-04, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 398, Loss: 8.459e-03, Loss_val: 4.037e-02, Best_loss: 3.299e-04, Time: 10.99, Learning Rate: 1.000e-03
# Epoch: 399, Loss: 1.164e-02, Loss_val: 2.519e-02, Best_loss: 3.299e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 400, Loss: 1.470e-02, Loss_val: 1.311e-02, Best_loss: 3.299e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 401, Loss: 1.615e-02, Loss_val: 5.107e-03, Best_loss: 3.299e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 402, Loss: 1.260e-02, Loss_val: 1.865e-02, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 403, Loss: 1.326e-02, Loss_val: 1.539e-02, Best_loss: 3.299e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 404, Loss: 1.141e-02, Loss_val: 2.456e-02, Best_loss: 3.299e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 405, Loss: 1.341e-02, Loss_val: 1.426e-02, Best_loss: 3.299e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 406, Loss: 1.339e-02, Loss_val: 1.243e-02, Best_loss: 3.299e-04, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 407, Loss: 1.595e-02, Loss_val: 9.641e-04, Best_loss: 3.299e-04, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 408, Loss: 1.594e-02, Loss_val: 9.411e-04, Best_loss: 3.299e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 409, Loss: 1.226e-02, Loss_val: 1.595e-02, Best_loss: 3.299e-04, Time: 11.03, Learning Rate: 1.000e-03
# Epoch: 410, Loss: 1.265e-02, Loss_val: 1.323e-02, Best_loss: 3.299e-04, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 411, Loss: 1.039e-02, Loss_val: 2.375e-02, Best_loss: 3.299e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 412, Loss: 1.250e-02, Loss_val: 1.347e-02, Best_loss: 3.299e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 413, Loss: 1.244e-02, Loss_val: 1.230e-02, Best_loss: 3.299e-04, Time: 11.14, Learning Rate: 1.000e-03
# Epoch: 414, Loss: 1.158e-02, Loss_val: 1.594e-02, Best_loss: 3.299e-04, Time: 11.04, Learning Rate: 1.000e-03
# Epoch: 415, Loss: 1.421e-02, Loss_val: 3.867e-03, Best_loss: 3.299e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 416, Loss: 1.460e-02, Loss_val: 9.153e-04, Best_loss: 3.299e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 417, Loss: 1.141e-02, Loss_val: 1.484e-02, Best_loss: 3.299e-04, Time: 11.07, Learning Rate: 1.000e-03
# Epoch: 418, Loss: 9.958e-03, Loss_val: 2.105e-02, Best_loss: 3.299e-04, Time: 11.00, Learning Rate: 1.000e-03
# Epoch: 419, Loss: 1.133e-02, Loss_val: 1.387e-02, Best_loss: 3.299e-04, Time: 11.05, Learning Rate: 1.000e-03
# Epoch: 420, Loss: 6.988e-03, Loss_val: 3.318e-02, Best_loss: 3.299e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 421, Loss: 1.109e-02, Loss_val: 1.435e-02, Best_loss: 3.299e-04, Time: 10.98, Learning Rate: 1.000e-03
# Epoch: 422, Loss: 1.323e-02, Loss_val: 3.937e-03, Best_loss: 3.299e-04, Time: 11.02, Learning Rate: 1.000e-03
# Epoch: 423, Loss: 1.063e-02, Loss_val: 1.549e-02, Best_loss: 3.299e-04, Time: 11.11, Learning Rate: 1.000e-03
# Epoch: 424, Loss: 1.142e-02, Loss_val: 1.139e-02, Best_loss: 3.299e-04, Time: 11.01, Learning Rate: 1.000e-03
# Epoch: 425, Loss: 1.055e-02, Loss_val: 1.455e-02, Best_loss: 3.299e-04, Time: 11.06, Learning Rate: 1.000e-03
# Epoch: 426, Loss: 1.275e-02, Loss_val: 4.315e-03, Best_loss: 3.299e-04, Time: 11.12, Learning Rate: 1.000e-03
# Epoch: 427, Loss: 1.085e-02, Loss_val: 1.211e-02, Best_loss: 3.299e-04, Time: 11.01, Learning Rate: 1.000e-03
# ...
# Epoch: 4878, Loss: 6.359e-04, Loss_val: 6.348e-04, Best_loss: 2.109e-05, Time: 11.33, Learning Rate: 1.000e-03
# Epoch: 4879, Loss: 6.110e-04, Loss_val: 7.951e-04, Best_loss: 2.109e-05, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 4880, Loss: 6.513e-04, Loss_val: 6.817e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4881, Loss: 7.253e-04, Loss_val: 7.207e-04, Best_loss: 2.109e-05, Time: 11.33, Learning Rate: 1.000e-03
# Epoch: 4882, Loss: 8.398e-04, Loss_val: 9.303e-04, Best_loss: 2.109e-05, Time: 11.20, Learning Rate: 1.000e-03
# Epoch: 4883, Loss: 7.527e-04, Loss_val: 9.504e-04, Best_loss: 2.109e-05, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 4884, Loss: 5.031e-04, Loss_val: 7.131e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4885, Loss: 4.814e-04, Loss_val: 4.721e-04, Best_loss: 2.109e-05, Time: 11.34, Learning Rate: 1.000e-03
# Epoch: 4886, Loss: 6.179e-04, Loss_val: 6.547e-04, Best_loss: 2.109e-05, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 4887, Loss: 6.719e-04, Loss_val: 6.621e-04, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Epoch: 4888, Loss: 5.119e-04, Loss_val: 5.520e-04, Best_loss: 2.109e-05, Time: 11.38, Learning Rate: 1.000e-03
# Epoch: 4889, Loss: 4.248e-04, Loss_val: 4.062e-04, Best_loss: 2.109e-05, Time: 11.27, Learning Rate: 1.000e-03
# Epoch: 4890, Loss: 5.342e-04, Loss_val: 4.127e-04, Best_loss: 2.109e-05, Time: 11.27, Learning Rate: 1.000e-03
# Epoch: 4891, Loss: 5.758e-04, Loss_val: 5.065e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4892, Loss: 4.626e-04, Loss_val: 3.777e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4893, Loss: 3.645e-04, Loss_val: 4.726e-04, Best_loss: 2.109e-05, Time: 11.20, Learning Rate: 1.000e-03
# Epoch: 4894, Loss: 4.273e-04, Loss_val: 6.584e-04, Best_loss: 2.109e-05, Time: 11.26, Learning Rate: 1.000e-03
# Epoch: 4895, Loss: 4.411e-04, Loss_val: 5.921e-04, Best_loss: 2.109e-05, Time: 11.31, Learning Rate: 1.000e-03
# Epoch: 4896, Loss: 3.951e-04, Loss_val: 3.022e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4897, Loss: 3.604e-04, Loss_val: 3.029e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4898, Loss: 3.805e-04, Loss_val: 4.303e-04, Best_loss: 2.109e-05, Time: 11.40, Learning Rate: 1.000e-03
# Epoch: 4899, Loss: 3.629e-04, Loss_val: 3.944e-04, Best_loss: 2.109e-05, Time: 11.20, Learning Rate: 1.000e-03
# Epoch: 4900, Loss: 9.462e-04, Loss_val: 7.892e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4901, Loss: 1.060e-03, Loss_val: 1.047e-03, Best_loss: 2.109e-05, Time: 11.31, Learning Rate: 1.000e-03
# Epoch: 4902, Loss: 1.187e-03, Loss_val: 1.183e-03, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Epoch: 4903, Loss: 8.813e-04, Loss_val: 8.908e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4904, Loss: 6.773e-04, Loss_val: 5.564e-04, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Epoch: 4905, Loss: 6.277e-04, Loss_val: 6.647e-04, Best_loss: 2.109e-05, Time: 11.33, Learning Rate: 1.000e-03
# Epoch: 4906, Loss: 7.336e-04, Loss_val: 8.070e-04, Best_loss: 2.109e-05, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 4907, Loss: 8.435e-04, Loss_val: 8.840e-04, Best_loss: 2.109e-05, Time: 11.20, Learning Rate: 1.000e-03
# Epoch: 4908, Loss: 8.541e-04, Loss_val: 7.805e-04, Best_loss: 2.109e-05, Time: 11.37, Learning Rate: 1.000e-03
# Epoch: 4909, Loss: 7.420e-04, Loss_val: 7.076e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4910, Loss: 6.288e-04, Loss_val: 6.562e-04, Best_loss: 2.109e-05, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 4911, Loss: 5.909e-04, Loss_val: 6.797e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4912, Loss: 6.717e-04, Loss_val: 5.069e-04, Best_loss: 2.109e-05, Time: 11.26, Learning Rate: 1.000e-03
# Epoch: 4913, Loss: 6.811e-04, Loss_val: 7.638e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4914, Loss: 6.858e-04, Loss_val: 7.390e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4915, Loss: 6.179e-04, Loss_val: 7.581e-04, Best_loss: 2.109e-05, Time: 11.28, Learning Rate: 1.000e-03
# Epoch: 4916, Loss: 6.259e-04, Loss_val: 4.528e-04, Best_loss: 2.109e-05, Time: 11.17, Learning Rate: 1.000e-03
# Epoch: 4917, Loss: 5.668e-04, Loss_val: 5.671e-04, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Epoch: 4918, Loss: 6.050e-04, Loss_val: 4.137e-04, Best_loss: 2.109e-05, Time: 11.34, Learning Rate: 1.000e-03
# Epoch: 4919, Loss: 5.610e-04, Loss_val: 6.762e-04, Best_loss: 2.109e-05, Time: 11.26, Learning Rate: 1.000e-03
# Epoch: 4920, Loss: 5.855e-04, Loss_val: 5.802e-04, Best_loss: 2.109e-05, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 4921, Loss: 5.639e-04, Loss_val: 5.984e-04, Best_loss: 2.109e-05, Time: 11.30, Learning Rate: 1.000e-03
# Epoch: 4922, Loss: 5.659e-04, Loss_val: 4.195e-04, Best_loss: 2.109e-05, Time: 11.42, Learning Rate: 1.000e-03
# Epoch: 4923, Loss: 5.430e-04, Loss_val: 3.943e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4924, Loss: 5.130e-04, Loss_val: 4.989e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4925, Loss: 5.096e-04, Loss_val: 5.173e-04, Best_loss: 2.109e-05, Time: 11.38, Learning Rate: 1.000e-03
# Epoch: 4926, Loss: 5.065e-04, Loss_val: 5.614e-04, Best_loss: 2.109e-05, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 4927, Loss: 4.994e-04, Loss_val: 5.306e-04, Best_loss: 2.109e-05, Time: 11.23, Learning Rate: 1.000e-03
# Epoch: 4928, Loss: 4.464e-04, Loss_val: 6.709e-04, Best_loss: 2.109e-05, Time: 11.27, Learning Rate: 1.000e-03
# Epoch: 4929, Loss: 4.651e-04, Loss_val: 4.979e-04, Best_loss: 2.109e-05, Time: 11.32, Learning Rate: 1.000e-03
# Epoch: 4930, Loss: 4.826e-04, Loss_val: 3.809e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4931, Loss: 4.719e-04, Loss_val: 4.437e-04, Best_loss: 2.109e-05, Time: 11.33, Learning Rate: 1.000e-03
# Epoch: 4932, Loss: 4.639e-04, Loss_val: 4.959e-04, Best_loss: 2.109e-05, Time: 11.42, Learning Rate: 1.000e-03
# Epoch: 4933, Loss: 4.593e-04, Loss_val: 4.900e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4934, Loss: 4.286e-04, Loss_val: 5.758e-04, Best_loss: 2.109e-05, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 4935, Loss: 4.673e-04, Loss_val: 3.236e-04, Best_loss: 2.109e-05, Time: 11.42, Learning Rate: 1.000e-03
# Epoch: 4936, Loss: 4.264e-04, Loss_val: 4.678e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4937, Loss: 4.487e-04, Loss_val: 3.442e-04, Best_loss: 2.109e-05, Time: 11.28, Learning Rate: 1.000e-03
# Epoch: 4938, Loss: 4.224e-04, Loss_val: 4.297e-04, Best_loss: 2.109e-05, Time: 11.23, Learning Rate: 1.000e-03
# Epoch: 4939, Loss: 4.152e-04, Loss_val: 4.066e-04, Best_loss: 2.109e-05, Time: 11.41, Learning Rate: 1.000e-03
# Epoch: 4940, Loss: 4.100e-04, Loss_val: 3.920e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4941, Loss: 4.113e-04, Loss_val: 3.439e-04, Best_loss: 2.109e-05, Time: 11.28, Learning Rate: 1.000e-03
# Epoch: 4942, Loss: 4.137e-04, Loss_val: 3.086e-04, Best_loss: 2.109e-05, Time: 11.48, Learning Rate: 1.000e-03
# Epoch: 4943, Loss: 4.202e-04, Loss_val: 2.765e-04, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Epoch: 4944, Loss: 3.549e-04, Loss_val: 5.362e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4945, Loss: 3.687e-04, Loss_val: 4.398e-04, Best_loss: 2.109e-05, Time: 11.31, Learning Rate: 1.000e-03
# Epoch: 4946, Loss: 3.966e-04, Loss_val: 2.850e-04, Best_loss: 2.109e-05, Time: 11.29, Learning Rate: 1.000e-03
# Epoch: 4947, Loss: 3.770e-04, Loss_val: 3.790e-04, Best_loss: 2.109e-05, Time: 11.46, Learning Rate: 1.000e-03
# Epoch: 4948, Loss: 3.583e-04, Loss_val: 4.359e-04, Best_loss: 2.109e-05, Time: 11.34, Learning Rate: 1.000e-03
# Epoch: 4949, Loss: 3.660e-04, Loss_val: 3.446e-04, Best_loss: 2.109e-05, Time: 11.54, Learning Rate: 1.000e-03
# Epoch: 4950, Loss: 3.565e-04, Loss_val: 3.433e-04, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Epoch: 4951, Loss: 3.194e-04, Loss_val: 4.982e-04, Best_loss: 2.109e-05, Time: 11.29, Learning Rate: 1.000e-03
# Epoch: 4952, Loss: 3.590e-04, Loss_val: 3.003e-04, Best_loss: 2.109e-05, Time: 11.35, Learning Rate: 1.000e-03
# Epoch: 4953, Loss: 3.492e-04, Loss_val: 3.301e-04, Best_loss: 2.109e-05, Time: 11.22, Learning Rate: 1.000e-03
# Epoch: 4954, Loss: 3.271e-04, Loss_val: 4.326e-04, Best_loss: 2.109e-05, Time: 11.26, Learning Rate: 1.000e-03
# Epoch: 4955, Loss: 3.185e-04, Loss_val: 4.897e-04, Best_loss: 2.109e-05, Time: 11.28, Learning Rate: 1.000e-03
# Epoch: 4956, Loss: 3.272e-04, Loss_val: 4.585e-04, Best_loss: 2.109e-05, Time: 11.35, Learning Rate: 1.000e-03
# Epoch: 4957, Loss: 3.444e-04, Loss_val: 3.890e-04, Best_loss: 2.109e-05, Time: 11.19, Learning Rate: 1.000e-03
# Epoch: 4958, Loss: 3.573e-04, Loss_val: 3.636e-04, Best_loss: 2.109e-05, Time: 11.37, Learning Rate: 1.000e-03
# Epoch: 4959, Loss: 3.813e-04, Loss_val: 2.874e-04, Best_loss: 2.109e-05, Time: 11.52, Learning Rate: 1.000e-03
# Epoch: 4960, Loss: 3.661e-04, Loss_val: 4.315e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4961, Loss: 4.201e-04, Loss_val: 3.135e-04, Best_loss: 2.109e-05, Time: 11.23, Learning Rate: 1.000e-03
# Epoch: 4962, Loss: 3.748e-04, Loss_val: 4.707e-04, Best_loss: 2.109e-05, Time: 11.33, Learning Rate: 1.000e-03
# Epoch: 4963, Loss: 3.582e-04, Loss_val: 3.694e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4964, Loss: 3.490e-04, Loss_val: 2.123e-04, Best_loss: 2.109e-05, Time: 11.15, Learning Rate: 1.000e-03
# Epoch: 4965, Loss: 2.848e-04, Loss_val: 3.156e-04, Best_loss: 2.109e-05, Time: 11.28, Learning Rate: 1.000e-03
# Epoch: 4966, Loss: 2.488e-04, Loss_val: 3.518e-04, Best_loss: 2.109e-05, Time: 11.30, Learning Rate: 1.000e-03
# Epoch: 4967, Loss: 2.301e-04, Loss_val: 3.800e-04, Best_loss: 2.109e-05, Time: 11.13, Learning Rate: 1.000e-03
# Epoch: 4968, Loss: 2.538e-04, Loss_val: 2.973e-04, Best_loss: 2.109e-05, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 4969, Loss: 2.825e-04, Loss_val: 2.790e-04, Best_loss: 2.109e-05, Time: 11.35, Learning Rate: 1.000e-03
# Epoch: 4970, Loss: 2.708e-04, Loss_val: 3.980e-04, Best_loss: 2.109e-05, Time: 11.26, Learning Rate: 1.000e-03
# Epoch: 4971, Loss: 3.156e-04, Loss_val: 2.203e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4972, Loss: 2.853e-04, Loss_val: 3.161e-04, Best_loss: 2.109e-05, Time: 11.29, Learning Rate: 1.000e-03
# Epoch: 4973, Loss: 2.841e-04, Loss_val: 3.327e-04, Best_loss: 2.109e-05, Time: 11.38, Learning Rate: 1.000e-03
# Epoch: 4974, Loss: 3.680e-04, Loss_val: 1.778e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4975, Loss: 5.627e-04, Loss_val: 4.551e-04, Best_loss: 2.109e-05, Time: 11.27, Learning Rate: 1.000e-03
# Epoch: 4976, Loss: 3.379e-04, Loss_val: 3.309e-04, Best_loss: 2.109e-05, Time: 11.36, Learning Rate: 1.000e-03
# Epoch: 4977, Loss: 4.034e-04, Loss_val: 5.465e-04, Best_loss: 2.109e-05, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 4978, Loss: 2.919e-04, Loss_val: 3.615e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4979, Loss: 3.479e-04, Loss_val: 4.283e-04, Best_loss: 2.109e-05, Time: 11.66, Learning Rate: 1.000e-03
# Epoch: 4980, Loss: 3.610e-04, Loss_val: 4.967e-04, Best_loss: 2.109e-05, Time: 11.30, Learning Rate: 1.000e-03
# Epoch: 4981, Loss: 3.031e-04, Loss_val: 3.136e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4982, Loss: 3.172e-04, Loss_val: 3.517e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4983, Loss: 3.003e-04, Loss_val: 5.030e-04, Best_loss: 2.109e-05, Time: 11.38, Learning Rate: 1.000e-03
# Epoch: 4984, Loss: 3.126e-04, Loss_val: 3.042e-04, Best_loss: 2.109e-05, Time: 11.18, Learning Rate: 1.000e-03
# Epoch: 4985, Loss: 2.895e-04, Loss_val: 4.156e-04, Best_loss: 2.109e-05, Time: 11.20, Learning Rate: 1.000e-03
# Epoch: 4986, Loss: 2.511e-04, Loss_val: 4.412e-04, Best_loss: 2.109e-05, Time: 11.52, Learning Rate: 1.000e-03
# Epoch: 4987, Loss: 3.039e-04, Loss_val: 1.213e-04, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Epoch: 4988, Loss: 2.863e-04, Loss_val: 3.667e-04, Best_loss: 2.109e-05, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 4989, Loss: 2.412e-04, Loss_val: 4.465e-04, Best_loss: 2.109e-05, Time: 11.23, Learning Rate: 1.000e-03
# Epoch: 4990, Loss: 2.656e-04, Loss_val: 2.391e-04, Best_loss: 2.109e-05, Time: 11.30, Learning Rate: 1.000e-03
# Epoch: 4991, Loss: 2.767e-04, Loss_val: 2.972e-04, Best_loss: 2.109e-05, Time: 11.16, Learning Rate: 1.000e-03
# Epoch: 4992, Loss: 2.671e-04, Loss_val: 3.072e-04, Best_loss: 2.109e-05, Time: 11.21, Learning Rate: 1.000e-03
# Epoch: 4993, Loss: 2.616e-04, Loss_val: 3.100e-04, Best_loss: 2.109e-05, Time: 11.32, Learning Rate: 1.000e-03
# Epoch: 4994, Loss: 2.496e-04, Loss_val: 3.734e-04, Best_loss: 2.109e-05, Time: 11.23, Learning Rate: 1.000e-03
# Epoch: 4995, Loss: 2.461e-04, Loss_val: 3.194e-04, Best_loss: 2.109e-05, Time: 11.24, Learning Rate: 1.000e-03
# Epoch: 4996, Loss: 2.756e-04, Loss_val: 1.513e-04, Best_loss: 2.109e-05, Time: 11.29, Learning Rate: 1.000e-03
# Epoch: 4997, Loss: 2.595e-04, Loss_val: 2.904e-04, Best_loss: 2.109e-05, Time: 11.26, Learning Rate: 1.000e-03
# Epoch: 4998, Loss: 2.514e-04, Loss_val: 2.914e-04, Best_loss: 2.109e-05, Time: 11.23, Learning Rate: 1.000e-03
# Epoch: 4999, Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05, Time: 11.25, Learning Rate: 1.000e-03
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# Loss: 2.559e-04, Loss_val: 2.398e-04, Best_loss: 2.109e-05
# INFO:tensorflow:Optimization terminated with:
#   Message: b'CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH'
#   Objective function value: 0.000256
#   Number of iterations: 1
#   Number of functions evaluations: 31
# C:\Users\livin\anaconda3\envs\lstm\lib\site-packages\ipykernel_launcher.py:409: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
